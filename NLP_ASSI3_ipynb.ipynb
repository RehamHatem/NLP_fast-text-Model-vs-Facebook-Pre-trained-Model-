# %%
import json
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import spacy
# Download necessary NLTK resources
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Initialize WordNet Lemmatizer
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
def preprocess_text(text):
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Convert text to lowercase
    text = text.lower()
    # Tokenize the text
    tokens = word_tokenize(text)
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]
    # Lemmatization using NLTK
    tokens = [lemmatizer.lemmatize(word) for word in tokens]
     # Remove words with 3 characters or fewer
    tokens = [word for word in tokens if len(word) > 3]
    # Join the tokens back into a single string
    preprocessed_text = ' '.join(tokens)

    return preprocessed_text

# %%
# Open the file containing the JSON data
print("Opening file...")
with open("/content/yelp_academic_dataset_tip.json", "r") as file:
    print("File opened successfully.")

    preprocessed_corpus = []

    # Read each line and process it as JSON
    print("Processing JSON data...")
    for line in file:
        try:
            # Parse the JSON data from the current line
            json_data = json.loads(line)
            # Extract the "text" attribute from the JSON object
            text_attribute = json_data.get("text")
            # Preprocess the text
            preprocessed_text = preprocess_text(text_attribute)
            # Append the preprocessed text to the corpus
            preprocessed_corpus.append(preprocessed_text)
        except json.JSONDecodeError:
            print("Error: Failed to parse JSON data in line:", line)
    print("JSON data processed successfully.")

print("Number of preprocessed text attributes in the corpus:", len(preprocessed_corpus))
# Out:
# Opening file...
# File opened successfully.
# Processing JSON data...
# Error: Failed to parse JSON data in line: "business_id":"mlaj6BRLOVtlEMRTZhUVvw","text":"You can never go wrong with the roasted veggie sandwich.","date":"2010-11-23 17:33:55","compliment_count":0}
#
# Error: Failed to parse JSON data in line: {"user_id":"a93yzcakAnlq0hwpEL_MGg","business_id":"
# JSON data processed successfully.
# Number of preprocessed text attributes in the corpus: 138008

# %%
import json
from gensim.models.fasttext import FastText
from gensim.utils import simple_preprocess

# Tokenize the preprocessed text
tokenized_corpus = [simple_preprocess(text) for text in preprocessed_corpus]

# Set parameters for the FastText model
vector_size = 100
window_size = 5
min_count = 3
sg = 3

# Create and train the FastText model
print("Training FastText model...")
model = FastText(
    sentences=tokenized_corpus,
    vector_size=vector_size,
    window=window_size,
    min_count=min_count,
    sg=sg
)
print("FastText model trained successfully.")
model.save("fasttext_model")
# Out:
# Training FastText model...
# FastText model trained successfully.

# %%
# Load the trained FastText model
print("Loading trained FastText model...")
model = FastText.load("fasttext_model")
print("Model loaded successfully.")
# Out:
# Loading trained FastText model...
# Model loaded successfully.

# %%
similar_words = model.wv.most_similar("love", topn=10)
# Print the similar words
print("Words similar to 'love':")
for word, similarity in similar_words:
    print(f"{word}: {similarity}")
# Out:
# Words similar to 'love':
# lovelove: 0.9332840442657471
# lovey: 0.8930991291999817
# lovin: 0.8246676325798035
# lover: 0.7998213768005371
# loved: 0.7877277135848999
# awesome: 0.7859285473823547
# clove: 0.784860372543335
# glove: 0.7801545262336731
# fantabulous: 0.7760823965072632
# amazinggg: 0.7753641605377197

# %%
# Function to find nearest words to a given list of words
def find_nearest_words(words_list, topn=10):
    nearest_words_dict = {}
    for word in words_list:
        try:
            # Find nearest words
            nearest_words = model.wv.most_similar(word, topn=topn)
            nearest_words_dict[word] = nearest_words
        except KeyError:
            nearest_words_dict[word] = f"'{word}' not in vocabulary."
    return nearest_words_dict

input_words = ["stop", "play", "delicious", "eat", "game", "self", "phone", "grow", "happy", "sad",
               "fun", "interesting", "boring", "exciting", "tired", "sleepy", "energetic", "lazy",
               "book", "movie", "music", "dance", "sing", "art"]
nearest_words_dict = find_nearest_words(input_words)

# Print the nearest words and their similarity scores for each input word
for word, nearest_words in nearest_words_dict.items():
    print(f"Nearest words to '{word}':")
    for nearest_word, similarity_score in nearest_words:
        print(f"Word: {nearest_word}, Similarity: {similarity_score}")
    print()
# Out:
# Loading trained FastText model...
# Model loaded successfully.
# Nearest words to 'stop':
# Word: pokestop, Similarity: 0.7930882573127747
# Word: stopped, Similarity: 0.7513830661773682
# Word: stoudts, Similarity: 0.7495892643928528
# Word: stove, Similarity: 0.743057131767273
# Word: staple, Similarity: 0.741254985332489
# Word: stollen, Similarity: 0.7346358299255371
# Word: avis, Similarity: 0.7276335954666138
# Word: ihop, Similarity: 0.7270922064781189
# Word: grab, Similarity: 0.7164693474769592
# Word: lucas, Similarity: 0.7155646681785583
#
# Nearest words to 'play':
# Word: playdoh, Similarity: 0.9583803415298462
# Word: playin, Similarity: 0.9358537197113037
# Word: playoff, Similarity: 0.9121178388595581
# Word: playing, Similarity: 0.8847506642341614
# Word: playground, Similarity: 0.8666591644287109
# Word: playtime, Similarity: 0.8618835210800171
# Word: player, Similarity: 0.861743152141571
# Word: video, Similarity: 0.8402920961380005
# Word: played, Similarity: 0.8283042311668396
# Word: juke, Similarity: 0.8283034563064575
#
# Nearest words to 'delicious':
# Word: deeeelicious, Similarity: 0.9697501063346863
# Word: delicioso, Similarity: 0.9628531336784363
# Word: deliciously, Similarity: 0.9597393870353699
# Word: deliscious, Similarity: 0.956800103187561
# Word: duhlicious, Similarity: 0.9543184638023376
# Word: deliciousness, Similarity: 0.9465327858924866
# Word: delicous, Similarity: 0.9359076619148254
# Word: delish, Similarity: 0.9286706447601318
# Word: delcious, Similarity: 0.8940948247909546
# Word: tasty, Similarity: 0.8878064155578613
#
# Nearest words to 'eat':
# Word: caveat, Similarity: 0.875234067440033
# Word: cheat, Similarity: 0.8701727986335754
# Word: heartbeat, Similarity: 0.8498313426971436
# Word: threat, Similarity: 0.8278576731681824
# Word: buckwheat, Similarity: 0.8266974687576294
# Word: nonmeat, Similarity: 0.8245462775230408
# Word: allucaneat, Similarity: 0.8214414119720459
# Word: beatles, Similarity: 0.8147926330566406
# Word: besitos, Similarity: 0.8067761659622192
# Word: beat, Similarity: 0.8043155670166016
#
# Nearest words to 'game':
# Word: gamey, Similarity: 0.8948591351509094
# Word: ballgame, Similarity: 0.8911533355712891
# Word: pregame, Similarity: 0.8082451224327087
# Word: gamedays, Similarity: 0.8070684671401978
# Word: bball, Similarity: 0.8039003610610962
# Word: football, Similarity: 0.8028815388679504
# Word: gawd, Similarity: 0.7997012734413147
# Word: baseball, Similarity: 0.7987691760063171
# Word: basketball, Similarity: 0.7953905463218689
# Word: playoff, Similarity: 0.7948114275932312
#
# Nearest words to 'self':
# Word: urself, Similarity: 0.9110803604125977
# Word: yoself, Similarity: 0.8956155776977539
# Word: selfcheckout, Similarity: 0.8626994490623474
# Word: ipads, Similarity: 0.8328153491020203
# Word: ample, Similarity: 0.8319987058639526
# Word: utilize, Similarity: 0.8285963535308838
# Word: bypass, Similarity: 0.8265584707260132
# Word: vault, Similarity: 0.8240369558334351
# Word: selfserve, Similarity: 0.822433352470398
# Word: registered, Similarity: 0.8209576606750488
#
# Nearest words to 'phone':
# Word: iphone, Similarity: 0.9694530367851257
# Word: telephone, Similarity: 0.9372785687446594
# Word: cellphone, Similarity: 0.932598888874054
# Word: earphone, Similarity: 0.9050306677818298
# Word: smartphone, Similarity: 0.9011109471321106
# Word: iphones, Similarity: 0.89695805311203
# Word: headphone, Similarity: 0.8818812370300293
# Word: number, Similarity: 0.8712560534477234
# Word: answer, Similarity: 0.8680304288864136
# Word: contact, Similarity: 0.8628109097480774
#
# Nearest words to 'grow':
# Word: grownup, Similarity: 0.9158841967582703
# Word: tshirts, Similarity: 0.8943648338317871
# Word: grower, Similarity: 0.887477457523346
# Word: hammock, Similarity: 0.8860149383544922
# Word: bouncy, Similarity: 0.8816354870796204
# Word: rhythm, Similarity: 0.8812435269355774
# Word: bulldog, Similarity: 0.8809986114501953
# Word: tgif, Similarity: 0.880736768245697
# Word: iupui, Similarity: 0.8788524866104126
# Word: juke, Similarity: 0.8769683837890625
#
# Nearest words to 'happy':
# Word: happyhour, Similarity: 0.9091854095458984
# Word: unhappy, Similarity: 0.8461955189704895
# Word: happily, Similarity: 0.816753089427948
# Word: happier, Similarity: 0.7994066476821899
# Word: appys, Similarity: 0.785933256149292
# Word: apps, Similarity: 0.7788042426109314
# Word: pmcl, Similarity: 0.7787474989891052
# Word: monfri, Similarity: 0.7505204081535339
# Word: happiest, Similarity: 0.7481536865234375
# Word: appitizer, Similarity: 0.7405713796615601
#
# Nearest words to 'sad':
# Word: sabor, Similarity: 0.9159834384918213
# Word: saxbys, Similarity: 0.9002975225448608
# Word: sazarac, Similarity: 0.8916646838188171
# Word: sarcasm, Similarity: 0.8891992568969727
# Word: satsun, Similarity: 0.8885480165481567
# Word: salumi, Similarity: 0.8854923248291016
# Word: sarcones, Similarity: 0.8832045197486877
# Word: sara, Similarity: 0.8803508281707764
# Word: saag, Similarity: 0.8791547417640686
# Word: samurai, Similarity: 0.8783140778541565
#
# Nearest words to 'fun':
# Word: funk, Similarity: 0.9478760957717896
# Word: fund, Similarity: 0.9372656941413879
# Word: fuzzy, Similarity: 0.9366243481636047
# Word: junky, Similarity: 0.9278228878974915
# Word: rhythm, Similarity: 0.9254577159881592
# Word: majestic, Similarity: 0.9245606064796448
# Word: xoxo, Similarity: 0.9243952631950378
# Word: ferris, Similarity: 0.9227786660194397
# Word: jims, Similarity: 0.9212878346443176
# Word: micah, Similarity: 0.9195589423179626
#
# Nearest words to 'interesting':
# Word: interestingly, Similarity: 0.9591735601425171
# Word: interest, Similarity: 0.9177056550979614
# Word: resting, Similarity: 0.9153236150741577
# Word: inspiring, Similarity: 0.8991418480873108
# Word: intimidating, Similarity: 0.892280638217926
# Word: uninspiring, Similarity: 0.8919331431388855
# Word: testing, Similarity: 0.8794504404067993
# Word: crafting, Similarity: 0.868820071220398
# Word: consisting, Similarity: 0.8686003088951111
# Word: surprising, Similarity: 0.8597188591957092
#
# Nearest words to 'boring':
# Word: hiring, Similarity: 0.9375967979431152
# Word: daring, Similarity: 0.9355277419090271
# Word: uninspiring, Similarity: 0.9169080853462219
# Word: skimping, Similarity: 0.9112231731414795
# Word: buzzing, Similarity: 0.9101082682609558
# Word: lingering, Similarity: 0.9100082516670227
# Word: blaring, Similarity: 0.909192681312561
# Word: dying, Similarity: 0.9066160321235657
# Word: skiing, Similarity: 0.905237078666687
# Word: gosling, Similarity: 0.9047462940216064
#
# Nearest words to 'exciting':
# Word: fascinating, Similarity: 0.9306082129478455
# Word: decorating, Similarity: 0.9297167062759399
# Word: outing, Similarity: 0.9290734529495239
# Word: voting, Similarity: 0.9285769462585449
# Word: inviting, Similarity: 0.925156831741333
# Word: indulging, Similarity: 0.9224289655685425
# Word: resting, Similarity: 0.9193577766418457
# Word: tinting, Similarity: 0.9181287884712219
# Word: siting, Similarity: 0.9180245995521545
# Word: filming, Similarity: 0.916361391544342
#
# Nearest words to 'tired':
# Word: hired, Similarity: 0.9456633925437927
# Word: retired, Similarity: 0.9392704367637634
# Word: injured, Similarity: 0.9198534488677979
# Word: bored, Similarity: 0.9162730574607849
# Word: lifted, Similarity: 0.9079301357269287
# Word: dragged, Similarity: 0.9058783650398254
# Word: geared, Similarity: 0.9031651616096497
# Word: involved, Similarity: 0.902897298336029
# Word: stirred, Similarity: 0.9028252363204956
# Word: revamped, Similarity: 0.9014690518379211
#
# Nearest words to 'sleepy':
# Word: sleep, Similarity: 0.9774546027183533
# Word: asleep, Similarity: 0.9586478471755981
# Word: sleeve, Similarity: 0.9434477686882019
# Word: claustrophobic, Similarity: 0.9335645437240601
# Word: hammock, Similarity: 0.9323391914367676
# Word: dusty, Similarity: 0.9313093423843384
# Word: rugby, Similarity: 0.9311929941177368
# Word: piercings, Similarity: 0.9265869855880737
# Word: geez, Similarity: 0.923952579498291
# Word: rusty, Similarity: 0.9235165119171143
#
# Nearest words to 'energetic':
# Word: enthusiastic, Similarity: 0.9556034207344055
# Word: enthusiasm, Similarity: 0.9450836777687073
# Word: synthetic, Similarity: 0.9418658018112183
# Word: inappropriate, Similarity: 0.9365613460540771
# Word: cosmetic, Similarity: 0.9315817952156067
# Word: energy, Similarity: 0.9309993386268616
# Word: diabetic, Similarity: 0.9305529594421387
# Word: aesthetic, Similarity: 0.9295911192893982
# Word: appropriate, Similarity: 0.9286702275276184
# Word: enthusiast, Similarity: 0.9282925724983215
#
# Nearest words to 'lazy':
# Word: ammo, Similarity: 0.899451732635498
# Word: afternoon, Similarity: 0.8961495757102966
# Word: suds, Similarity: 0.8933933973312378
# Word: governor, Similarity: 0.8931064605712891
# Word: gypsy, Similarity: 0.8888129591941833
# Word: afterwork, Similarity: 0.8884598016738892
# Word: wahhhh, Similarity: 0.8856779932975769
# Word: mraz, Similarity: 0.8847622275352478
# Word: sleepy, Similarity: 0.8821203708648682
# Word: ruby, Similarity: 0.8811911344528198
#
# Nearest words to 'book':
# Word: bookshop, Similarity: 0.8811341524124146
# Word: rebook, Similarity: 0.872714102268219
# Word: textbook, Similarity: 0.8706260919570923
# Word: macbook, Similarity: 0.8649632930755615
# Word: booby, Similarity: 0.8524039387702942
# Word: booyah, Similarity: 0.8397146463394165
# Word: boob, Similarity: 0.8367442488670349
# Word: pocketbook, Similarity: 0.8358633518218994
# Word: bookstore, Similarity: 0.8244818449020386
# Word: requires, Similarity: 0.8165980577468872
#
# Nearest words to 'movie':
# Word: moviegoer, Similarity: 0.9356523752212524
# Word: premovie, Similarity: 0.8910366296768188
# Word: college, Similarity: 0.8444215655326843
# Word: theatre, Similarity: 0.8382541537284851
# Word: privilege, Similarity: 0.836264431476593
# Word: imax, Similarity: 0.8302565217018127
# Word: sneak, Similarity: 0.8267821073532104
# Word: golf, Similarity: 0.8260740041732788
# Word: volleyball, Similarity: 0.8215696811676025
# Word: bikers, Similarity: 0.82071852684021
#
# Nearest words to 'music':
# Word: musical, Similarity: 0.90767902135849
# Word: musician, Similarity: 0.8841722011566162
# Word: jazz, Similarity: 0.8214611411094666
# Word: band, Similarity: 0.8189963698387146
# Word: guitar, Similarity: 0.8033072352409363
# Word: jazzy, Similarity: 0.7990174293518066
# Word: piano, Similarity: 0.7892550826072693
# Word: playin, Similarity: 0.7871044278144836
# Word: acoustic, Similarity: 0.7806703448295593
# Word: playing, Similarity: 0.7675939202308655
#
# Nearest words to 'dance':
# Word: dancer, Similarity: 0.9438469409942627
# Word: guidance, Similarity: 0.9362999200820923
# Word: riddance, Similarity: 0.8966124653816223
# Word: dancing, Similarity: 0.894439697265625
# Word: performance, Similarity: 0.8851016163825989
# Word: guitar, Similarity: 0.8796515464782715
# Word: romance, Similarity: 0.8648779392242432
# Word: concert, Similarity: 0.8640302419662476
# Word: danny, Similarity: 0.859737753868103
# Word: elegance, Similarity: 0.8539581894874573
#
# Nearest words to 'sing':
# Word: singing, Similarity: 0.9482718110084534
# Word: loosing, Similarity: 0.9274041652679443
# Word: nursing, Similarity: 0.9261925220489502
# Word: voting, Similarity: 0.9249514937400818
# Word: taping, Similarity: 0.9245734810829163
# Word: fing, Similarity: 0.9206580519676208
# Word: bumping, Similarity: 0.9191819429397583
# Word: jonesing, Similarity: 0.9183906316757202
# Word: bing, Similarity: 0.9182271957397461
# Word: leasing, Similarity: 0.9153262972831726
#
# Nearest words to 'art':
# Word: artsy, Similarity: 0.9209185242652893
# Word: mozart, Similarity: 0.9194368124008179
# Word: bogart, Similarity: 0.904457151889801
# Word: fart, Similarity: 0.9033305644989014
# Word: arabic, Similarity: 0.8941159844398499
# Word: artisanal, Similarity: 0.8911940455436707
# Word: kmart, Similarity: 0.8855782747268677
# Word: artifact, Similarity: 0.8811234831809998
# Word: hart, Similarity: 0.8808817267417908
# Word: petsmart, Similarity: 0.8793545961380005

# %%
def find_furthest_words(words_list, topn=10):
    furthest_words_dict = {}
    for word in words_list:
        try:
            # the word vector
            word_vector = model.wv[word]
            # furthest words
            furthest_words = model.wv.similar_by_vector(-word_vector, topn=topn)
            furthest_words_dict[word] = furthest_words
        except KeyError:
            furthest_words_dict[word] = f"'{word}' not in vocabulary."
    return furthest_words_dict

input_words = ["stop", "play", "delicious", "eat", "game", "self", "phone", "grow", "happy", "sad",
               "fun", "interesting", "boring", "exciting", "tired", "sleepy", "energetic", "lazy",
               "book", "movie", "music", "dance", "sing", "art"]
furthest_words_dict = find_furthest_words(input_words)

# Print the furthest words and their similarity scores for each input word
for word, furthest_words in furthest_words_dict.items():
    print(f"Furthest words from '{word}':")
    for furthest_word, similarity_score in furthest_words:
        print(f"Word: {furthest_word}, Similarity: {similarity_score}")
    print()
# Out:
# Furthest words from 'stop':
# Word: onion, Similarity: -0.26433679461479187
# Word: cant, Similarity: -0.2758829891681671
# Word: vegetarian, Similarity: -0.29461660981178284
# Word: hair, Similarity: -0.2957654297351837
# Word: doesnt, Similarity: -0.2967579960823059
# Word: toni, Similarity: -0.29765549302101135
# Word: tender, Similarity: -0.3015691637992859
# Word: manager, Similarity: -0.31387823820114136
# Word: rice, Similarity: -0.3158303499221802
# Word: burger, Similarity: -0.31654056906700134
#
# Furthest words from 'play':
# Word: tasted, Similarity: -0.17939837276935577
# Word: toasted, Similarity: -0.20852871239185333
# Word: aged, Similarity: -0.21130476891994476
# Word: crusted, Similarity: -0.21937043964862823
# Word: worst, Similarity: -0.22429533302783966
# Word: addicted, Similarity: -0.22733747959136963
# Word: rated, Similarity: -0.23155486583709717
# Word: ever, Similarity: -0.23361249268054962
# Word: messed, Similarity: -0.2352067232131958
# Word: addict, Similarity: -0.23688194155693054
#
# Furthest words from 'delicious':
# Word: st, Similarity: -0.1564493328332901
# Word: direct, Similarity: -0.22763928771018982
# Word: rd, Similarity: -0.23249267041683197
# Word: bike, Similarity: -0.238157719373703
# Word: director, Similarity: -0.24277295172214508
# Word: haiku, Similarity: -0.24859558045864105
# Word: wear, Similarity: -0.25035932660102844
# Word: screen, Similarity: -0.25174641609191895
# Word: nd, Similarity: -0.2542645335197449
# Word: filth, Similarity: -0.2545159161090851
#
# Furthest words from 'eat':
# Word: renovated, Similarity: -0.3057892620563507
# Word: st, Similarity: -0.3112483620643616
# Word: rated, Similarity: -0.31252819299697876
# Word: recently, Similarity: -0.3161604404449463
# Word: manager, Similarity: -0.32895874977111816
# Word: closed, Similarity: -0.33136504888534546
# Word: haiku, Similarity: -0.33334586024284363
# Word: th, Similarity: -0.3358234167098999
# Word: located, Similarity: -0.33719149231910706
# Word: opened, Similarity: -0.34345704317092896
#
# Furthest words from 'game':
# Word: ever, Similarity: -0.10908681154251099
# Word: highly, Similarity: -0.15301111340522766
# Word: absolutely, Similarity: -0.15302008390426636
# Word: rated, Similarity: -0.1953667402267456
# Word: extremely, Similarity: -0.19817335903644562
# Word: salted, Similarity: -0.202906996011734
# Word: freshly, Similarity: -0.2090533971786499
# Word: tasted, Similarity: -0.20905859768390656
# Word: simply, Similarity: -0.21097636222839355
# Word: made, Similarity: -0.2140858918428421
#
# Furthest words from 'self':
# Word: wing, Similarity: -0.23322561383247375
# Word: lamb, Similarity: -0.27412354946136475
# Word: shrimp, Similarity: -0.2745770215988159
# Word: clam, Similarity: -0.2755947709083557
# Word: tuna, Similarity: -0.2791869640350342
# Word: bang, Similarity: -0.2821502983570099
# Word: spicy, Similarity: -0.2840254604816437
# Word: pork, Similarity: -0.28489524126052856
# Word: smoked, Similarity: -0.2873544991016388
# Word: margarita, Similarity: -0.28833866119384766
#
# Furthest words from 'phone':
# Word: nola, Similarity: -0.20296622812747955
# Word: yummy, Similarity: -0.20780494809150696
# Word: italian, Similarity: -0.21407029032707214
# Word: irish, Similarity: -0.21437561511993408
# Word: yumm, Similarity: -0.21588748693466187
# Word: bourbon, Similarity: -0.2181045562028885
# Word: choco, Similarity: -0.21965007483959198
# Word: taco, Similarity: -0.22596561908721924
# Word: orleans, Similarity: -0.22819159924983978
# Word: authentic, Similarity: -0.2282336950302124
#
# Furthest words from 'grow':
# Word: best, Similarity: -0.36744317412376404
# Word: ever, Similarity: -0.38722455501556396
# Word: thai, Similarity: -0.4019584059715271
# Word: rice, Similarity: -0.4093862473964691
# Word: served, Similarity: -0.4197467565536499
# Word: loved, Similarity: -0.42153510451316833
# Word: west, Similarity: -0.4225515127182007
# Word: worst, Similarity: -0.42707082629203796
# Word: french, Similarity: -0.43252983689308167
# Word: zest, Similarity: -0.4329286813735962
#
# Furthest words from 'happy':
# Word: ride, Similarity: -0.2477937787771225
# Word: youre, Similarity: -0.2528570592403412
# Word: using, Similarity: -0.2567276656627655
# Word: line, Similarity: -0.260365754365921
# Word: side, Similarity: -0.27126073837280273
# Word: health, Similarity: -0.2794618308544159
# Word: american, Similarity: -0.2843155562877655
# Word: wear, Similarity: -0.28474849462509155
# Word: entrance, Similarity: -0.28718605637550354
# Word: salt, Similarity: -0.28744056820869446
#
# Furthest words from 'sad':
# Word: bring, Similarity: -0.3501896560192108
# Word: free, Similarity: -0.3776020407676697
# Word: chair, Similarity: -0.385101318359375
# Word: st, Similarity: -0.3912370204925537
# Word: take, Similarity: -0.39127519726753235
# Word: dirty, Similarity: -0.39457568526268005
# Word: card, Similarity: -0.39694854617118835
# Word: clean, Similarity: -0.39903008937835693
# Word: king, Similarity: -0.40078800916671753
# Word: room, Similarity: -0.4010202884674072
#
# Furthest words from 'fun':
# Word: sandwich, Similarity: -0.4090508818626404
# Word: soup, Similarity: -0.4125842750072479
# Word: salad, Similarity: -0.42522093653678894
# Word: order, Similarity: -0.427178293466568
# Word: roll, Similarity: -0.4275132715702057
# Word: parking, Similarity: -0.44551992416381836
# Word: fresh, Similarity: -0.44841548800468445
# Word: room, Similarity: -0.4505116641521454
# Word: line, Similarity: -0.45743972063064575
# Word: delivery, Similarity: -0.46046650409698486
#
# Furthest words from 'interesting':
# Word: haiku, Similarity: -0.2707160413265228
# Word: park, Similarity: -0.2810989320278168
# Word: hair, Similarity: -0.288583904504776
# Word: nolahaiku, Similarity: -0.3076702952384949
# Word: massage, Similarity: -0.3122918903827667
# Word: parkin, Similarity: -0.3161528408527374
# Word: oyster, Similarity: -0.32034775614738464
# Word: birthday, Similarity: -0.33039146661758423
# Word: card, Similarity: -0.3329196274280548
# Word: nola, Similarity: -0.3465651869773865
#
# Furthest words from 'boring':
# Word: nola, Similarity: -0.2909224033355713
# Word: haiku, Similarity: -0.294208288192749
# Word: nolahaiku, Similarity: -0.3128287196159363
# Word: cake, Similarity: -0.32864120602607727
# Word: birthday, Similarity: -0.3421357274055481
# Word: chocolat, Similarity: -0.3476336896419525
# Word: massage, Similarity: -0.3516942262649536
# Word: chocolate, Similarity: -0.3530931770801544
# Word: oyster, Similarity: -0.35810452699661255
# Word: ever, Similarity: -0.36002880334854126
#
# Furthest words from 'exciting':
# Word: card, Similarity: -0.38069379329681396
# Word: salad, Similarity: -0.3970943093299866
# Word: charge, Similarity: -0.39807894825935364
# Word: ever, Similarity: -0.39824047684669495
# Word: side, Similarity: -0.4011966586112976
# Word: burger, Similarity: -0.4019557535648346
# Word: soup, Similarity: -0.40258607268333435
# Word: cake, Similarity: -0.4031108319759369
# Word: half, Similarity: -0.4035224914550781
# Word: cash, Similarity: -0.4046500027179718
#
# Furthest words from 'tired':
# Word: chocolat, Similarity: -0.3089306652545929
# Word: chocolate, Similarity: -0.326154500246048
# Word: nola, Similarity: -0.3297097980976105
# Word: burger, Similarity: -0.33310726284980774
# Word: taco, Similarity: -0.33524277806282043
# Word: chocolatey, Similarity: -0.3396229147911072
# Word: choco, Similarity: -0.35068193078041077
# Word: burrito, Similarity: -0.3573860824108124
# Word: smoke, Similarity: -0.3599105477333069
# Word: cheese, Similarity: -0.36399808526039124
#
# Furthest words from 'sleepy':
# Word: nola, Similarity: -0.43033045530319214
# Word: soup, Similarity: -0.4412131607532501
# Word: free, Similarity: -0.44128865003585815
# Word: include, Similarity: -0.446230411529541
# Word: includes, Similarity: -0.44642412662506104
# Word: birthday, Similarity: -0.4512232840061188
# Word: best, Similarity: -0.45149531960487366
# Word: fest, Similarity: -0.4542478024959564
# Word: salad, Similarity: -0.45693665742874146
# Word: west, Similarity: -0.4591560959815979
#
# Furthest words from 'energetic':
# Word: oyster, Similarity: -0.4055558741092682
# Word: king, Similarity: -0.41518476605415344
# Word: cake, Similarity: -0.42868706583976746
# Word: cheese, Similarity: -0.4287192225456238
# Word: chicken, Similarity: -0.43147698044776917
# Word: pizza, Similarity: -0.43201684951782227
# Word: wing, Similarity: -0.4453706741333008
# Word: onion, Similarity: -0.4470718502998352
# Word: roll, Similarity: -0.4506653845310211
# Word: closed, Similarity: -0.45216524600982666
#
# Furthest words from 'lazy':
# Word: dish, Similarity: -0.3818299174308777
# Word: tail, Similarity: -0.38209429383277893
# Word: rican, Similarity: -0.3850933015346527
# Word: fish, Similarity: -0.38882753252983093
# Word: taco, Similarity: -0.38988980650901794
# Word: pizza, Similarity: -0.390287846326828
# Word: cake, Similarity: -0.3917646110057831
# Word: beef, Similarity: -0.3987349569797516
# Word: cheese, Similarity: -0.40497156977653503
# Word: roll, Similarity: -0.4060949683189392
#
# Furthest words from 'book':
# Word: lemon, Similarity: -0.21694223582744598
# Word: potato, Similarity: -0.22006718814373016
# Word: smoked, Similarity: -0.22410260140895844
# Word: onion, Similarity: -0.233284592628479
# Word: perfecto, Similarity: -0.23790466785430908
# Word: topped, Similarity: -0.24510134756565094
# Word: slaw, Similarity: -0.2485773116350174
# Word: creamy, Similarity: -0.2493295669555664
# Word: crispy, Similarity: -0.24975886940956116
# Word: tasty, Similarity: -0.2512546181678772
#
# Furthest words from 'movie':
# Word: toasted, Similarity: -0.18392419815063477
# Word: tasted, Similarity: -0.21983173489570618
# Word: ever, Similarity: -0.2202761173248291
# Word: roasted, Similarity: -0.2251717448234558
# Word: baked, Similarity: -0.23334577679634094
# Word: french, Similarity: -0.2447851449251175
# Word: addict, Similarity: -0.24700501561164856
# Word: apple, Similarity: -0.24730171263217926
# Word: toast, Similarity: -0.24836350977420807
# Word: crusted, Similarity: -0.24860909581184387
#
# Furthest words from 'music':
# Word: paper, Similarity: -0.20251630246639252
# Word: double, Similarity: -0.21261417865753174
# Word: apple, Similarity: -0.22650961577892303
# Word: pick, Similarity: -0.22915905714035034
# Word: doubled, Similarity: -0.23288050293922424
# Word: topped, Similarity: -0.23725348711013794
# Word: addict, Similarity: -0.2385147660970688
# Word: dipped, Similarity: -0.24105305969715118
# Word: regret, Similarity: -0.2444317787885666
# Word: removed, Similarity: -0.2511892020702362
#
# Furthest words from 'dance':
# Word: toasted, Similarity: -0.2004188895225525
# Word: sliced, Similarity: -0.2109694629907608
# Word: bagel, Similarity: -0.2132163941860199
# Word: addict, Similarity: -0.22144202888011932
# Word: addicted, Similarity: -0.23677322268486023
# Word: tasted, Similarity: -0.2390294224023819
# Word: fresh, Similarity: -0.24004662036895752
# Word: crusted, Similarity: -0.24767275154590607
# Word: made, Similarity: -0.24989202618598938
# Word: seed, Similarity: -0.25522494316101074
#
# Furthest words from 'sing':
# Word: cake, Similarity: -0.23121915757656097
# Word: chocolat, Similarity: -0.2374206930398941
# Word: chocolate, Similarity: -0.2476736158132553
# Word: nola, Similarity: -0.2549460232257843
# Word: coffee, Similarity: -0.2563459873199463
# Word: chocolatey, Similarity: -0.2626171112060547
# Word: choco, Similarity: -0.2680097818374634
# Word: toast, Similarity: -0.2713264524936676
# Word: latte, Similarity: -0.2774951159954071
# Word: cafe, Similarity: -0.2795358896255493
#
# Furthest words from 'art':
# Word: burrito, Similarity: -0.32153815031051636
# Word: rice, Similarity: -0.32932353019714355
# Word: closed, Similarity: -0.33329689502716064
# Word: taco, Similarity: -0.3369583189487457
# Word: review, Similarity: -0.3473033905029297
# Word: pork, Similarity: -0.35950562357902527
# Word: worst, Similarity: -0.36770492792129517
# Word: went, Similarity: -0.36953791975975037
# Word: chicken, Similarity: -0.3750895857810974
# Word: star, Similarity: -0.37930747866630554
